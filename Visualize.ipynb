# %%
import numpy as np
import pandas as pd

# %%
# file csv
features_path ="C:/Users/Lenovo/Desktop/Processed/Features_Back.csv"
dataset = pd.read_csv(features_path, header=None)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3169 entries, 0 to 3168
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       3169 non-null   int64
#  1   1       3169 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.6 KB

# %%
dataset[0].value_counts()
# Out:
# 1    1103
# 2    1034
# 3    1032
# Name: 0, dtype: int64

# %%
# file csv
features_path ="C:/Users/Lenovo/Desktop/Processed/Features_Head.csv"
dataset = pd.read_csv(features_path, header=None)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1590 non-null   int64
#  1   1       1590 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 25.0 KB

# %%
dataset[0].value_counts()
# Out:
# 1    883
# 0    707
# Name: 0, dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1960 entries, 0 to 1959
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1960 non-null   int64
#  1   1       1960 non-null   float64
#  2   2       1960 non-null   float64
#  3   3       1960 non-null   float64
# dtypes: float64(3), int64(1)
# memory usage: 61.4 KB

# %%
dataset[0].value_counts()
# Out:
# 1    1213
# 0     747
# Name: 0, dtype: int64

# %%
# Visualize
import matplotlib.pyplot as plt
def visualize(X,y,colors):
    plt.scatter(X, y, c=colors)
# Set the title and labels
    plt.title('Scatter Plot')
    plt.xlabel('Index')
    plt.ylabel('Angle')
    plt.show()

# %%
# Head
# file csv
features_path ="C:/Users/Lenovo/Desktop/Processed/Features_Head.csv"
dataset = pd.read_csv(features_path, header=None)
y = dataset[1].values
X = list(range(len(y)))

labels = dataset[0].values
colors = []
for l in labels:
    if l == 0:
        colors.append('red')
    elif l == 1:
        colors.append('blue')
visualize(X, y,colors)

# %%
# Head
# file csv
features_path ="C:/Users/Lenovo/Desktop/Processed/Features_Back.csv"
dataset = pd.read_csv(features_path, header=None)
y = dataset[1].values
X = list(range(len(y)))

labels = dataset[0].values
colors = []
for l in labels:
    if l == 1:
        colors.append('red')
    elif l == 2:
        colors.append('blue')
    elif l == 3:
        colors.append('green')
visualize(X, y,colors)

# %%
correct_head_confused = dataset.loc[(dataset[1] == 1 ) & (dataset[4] < 150 ),0].values

wrong_head_confused = dataset.loc[(dataset[1] == 0 ) & (dataset[4] >= 150 ),0].values

# %%
folder_path = "D:/YOLO/runs/pose/predict"

new_folder_path = 'C:/Users/Lenovo/Desktop/DT/Removed/Head/1'

duplicate_images_confused(folder_path,new_folder_path,correct_head_confused)

# %%
folder_path = "D:/YOLO/runs/pose/predict"

new_folder_path = 'C:/Users/Lenovo/Desktop/DT/Removed/Head/0'

duplicate_images_confused(folder_path,new_folder_path,wrong_head_confused)

# %%
# Back

y = dataset[5].values
X = list(range(len(y)))

labels = dataset[2].values
colors = []
for l in labels:
    if l == 1:
        colors.append('red')
    elif l == 2:
        colors.append('blue')
    elif l == 3:
        colors.append('green')
visualize(X, y,colors)

# %%
correct_back_confused = dataset.loc[(dataset[2] == 1 ) & ((dataset[5] < 90 ) | (dataset[5] > 105 )),0].values

leaning_back_confused = dataset.loc[(dataset[2] == 2 ) & (dataset[5] <= 105 ),0].values

leaning_forward_confused = dataset.loc[(dataset[2] == 3 ) & (dataset[5] >= 90 ),0].values

# %%
folder_path = "D:/YOLO/runs/pose/predict"

new_folder_path = 'C:/Users/Lenovo/Desktop/DT/Removed/Back/3'

duplicate_images_confused(folder_path,new_folder_path,leaning_forward_confused)

# %%
# Left right

y = dataset[7].values
X = list(range(len(y)))

labels = dataset[3].values
colors = []
for l in labels:
    if l == 0:
        colors.append('red')
    elif l == 1:
        colors.append('blue')
visualize(X, y,colors)

# %%
correct_leg_confused = dataset.loc[(dataset[3] == 1 ) & (dataset[6] > 70 ) & (dataset[7] > 70 ) & (abs(dataset[7]-dataset[6])< 10),0].values

wrong_leg_confused = dataset.loc[(dataset[3] == 0 ) & (dataset[5] <= 105 ),0].values

# %%
folder_path = "D:/YOLO/runs/pose/predict"

new_folder_path = 'C:/Users/Lenovo/Desktop/DT/Removed/Back/3'

duplicate_images_confused(folder_path,new_folder_path,leaning_forward_confused)
